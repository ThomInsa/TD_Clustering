# %%
import os
os.chdir("/Users/thom/Personnel/Scolaire/Data Mining/TD Clustering")
print(os.getcwd())
# Out:
# /Users/thom/Personnel/Scolaire/Data Mining/TD Clustering

# %%
from scripts.main import *
from scripts.visualisation import *
import pandas as pd

# %%
data12 = pd.read_csv("data/example_12.csv")
data13 = pd.read_csv("data/example_13.csv")

plot_points_on_line(data12, "x")
plot_points_2d(data13, "x", "y")

# %%
k_means(data12, 3)
# Out:
# Initialized centroids:
# [[12.]
#  [ 4.]
#  [30.]]
# Iteration 1 / 100
#  Cluster sizes: [1 3 2]
#  Centroid shifts: [0. 0. 3.] max: 3.0
# Iteration 2 / 100
#  Cluster sizes: [1 3 2]
#  Centroid shifts: [0. 0. 0.] max: 0.0
# Converged at iteration 2, max shift 0
# Final centroids:
# [[12.]
#  [ 4.]
#  [27.]]
# Final SSE: 26
# (array([[12.],
#         [ 4.],
#         [27.]]),
#  np.float64(26.0))

# %%
k_means(data13, 3)
# Out:
# Initialized centroids:
# [[-2.  3.]
#  [ 2. -1.]
#  [ 1.  0.]]
# Iteration 1 / 100
#  Cluster sizes: [2 1 3]
#  Centroid shifts: [1.         0.         0.66666667] max: 1.0
# Iteration 2 / 100
#  Cluster sizes: [2 1 3]
#  Centroid shifts: [0. 0. 0.] max: 0.0
# Converged at iteration 2, max shift 0
# Final centroids:
# [[-2.          2.        ]
#  [ 2.         -1.        ]
#  [ 0.33333333  0.        ]]
# Final SSE: 12.6667
# (array([[-2.        ,  2.        ],
#         [ 2.        , -1.        ],
#         [ 0.33333333,  0.        ]]),
#  np.float64(12.666666666666668))
