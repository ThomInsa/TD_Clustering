# %%
import scripts.visualisation as vis
import pandas as pd
import os
print(os.getcwd())
# Out:
# /Users/thom/Personnel/Scolaire/Data Mining/TD Clustering/notebooks

# %%
df_country = pd.read_csv("../data/Country-data.csv")

# %%
vis.plot_feature_distributions(df = df_country)
